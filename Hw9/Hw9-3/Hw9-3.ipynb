# %%
import numpy as np

# %timeit sum([x for x in range(10_000_000)])

# %timeit np.arange(10_000_000).sum()
# Out:
# 811 ms ± 200 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 27.1 ms ± 571 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
